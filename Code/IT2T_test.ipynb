# %%
# notebook to test out capabilities of image-text to text models 
! pip install transformers einops pillow torch torchvision

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from PIL import Image

model_id = "vikhyatk/moondream2"
revision = "2024-04-02"
model = AutoModelForCausalLM.from_pretrained(
    model_id, trust_remote_code=True, revision=revision
)
tokenizer = AutoTokenizer.from_pretrained(model_id, revision=revision)

image = Image.open('')
enc_image = model.encode_image(image)
print(model.answer_question(enc_image, "Describe this image with a descriptive paragraph, capturing the most details as possible.", tokenizer))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 model_id = "vikhyatk/moondream2"
#       5 revision = "2024-04-02"
# ----> 6 model = AutoModelForCausalLM.from_pretrained(
#       7     model_id, trust_remote_code=True, revision=revision
#       8 )
#       9 tokenizer = AutoTokenizer.from_pretrained(model_id, revision=revision)
#      11 image = Image.open('')
#
# File ~/Documents/University/Learning_Based/Project/.venv/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:484, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     481 if commit_hash is None:
#     482     if not isinstance(config, PretrainedConfig):
#     483         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# ...
